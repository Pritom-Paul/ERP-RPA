# %% [markdown]
# Extract

# %%
import os
import re
import pdfplumber
import pandas as pd

pdf_dir = r"C:\Users\Altersense\Desktop\ERP-RPA\Challan"

for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, filename)
        print(f"\n{'='*80}")
        print(f"FILE: {filename}")
        print(f"{'='*80}")
        
        try:
            with pdfplumber.open(pdf_path) as pdf:
                for page_num, page in enumerate(pdf.pages, 1):
                    page_text = page.extract_text()
                    if page_text:
                        print(f"\n--- Page {page_num} ---")
                        print(page_text)
                    else:
                        print(f"\n--- Page {page_num} --- (No text found)")
                        
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
# Out:
# ================================================================================
# FILE: DC-25-2209.pdf
# ================================================================================
#
# --- Page 1 ---
# Bitopi Group
# Baridhi Garments Ltd.
# SFB# 7 & 8 (Ground Floor to 5th Floor) Cumilla EPZ, Cumilla, Bangladesh.
# Export Delivery Challan/Gate Pass
# SL No: DC-25-2209 Date: 25-May-2025
# To: Summit Alliance Port Ltd (SAPL) Driver Name: MD NURUL ISLAM
# Address: Katghar,South Patenga,Chattogram. Cell Number: 01874-836656
# Export L/C No : 554/564 License No: CG00561156H00001
# Buyer: H&M Truck No: DM-U-11-6456
# Vehicle Information: Cover Van Single Lock No: 1391917 Container SL No:
# S/N Description of Goods/PO Style Invoice No Qty No of Pkgs Remarks Net Weight Gross Weight
# 1 374509 MK Scott Reg Blosuon 41445825 440 23 ITW018 345.36 368.02
# 2 373318 ERICA Twill Jacket S2 41423325 177 11 TRW191 142.00 152.81
# 3 367576 JULES JACKET S2 41421825 1462 63 TRW059 678.22 763.76
# 4 367611 NICKY Jogger 3PACK S2 BGL 41424225 34 3 AUW270 19.41 22.01
# 5 367611 NICKY Jogger 3PACK S2 BGL 41424025 36 3 JPW171 21.30 23.90
# 6 367572 JULES JACKET S2 41421025 161 8 ITW128 76.49 84.37
# 7 367572 JULES JACKET S2 41421125 88 5 TRW191 40.87 45.77
# 8 247879 SOFIE QUILTED JKT S1 41420525 937 81 CLW093 403.34 495.68
# 9 379606 NICKY Jogger 3PACK S2 BGL 41424425 543 34 ITW128 307.16 338.10
# 10 379606 NICKY Jogger 3PACK S2 BGL 41424425 87 7 TRW191 49.61 55.72
# 11 378602 MK Scott Reg Blosuon 41424525 96 6 ITW128 76.33 84.49
# 12 378602 MK Scott Reg Blosuon 41447625 51 4 TRW191 40.68 45.98
# 13 357676 MK Scott Reg Blosuon 41447125 590 32 JPW053 467.32 501.17
# 14 378600 MK Scott Reg Blosuon 41446725 224 14 ITW128 176.80 195.70
# 15 257721 FINN Chore Jacket S1 41420625 345 10 CLW093 108.05 118.06
# Total: 5271 304
# Received on behalf of Transport agency Store Manager HR/Admin Authorised Signature
# Page 1 of 1 Print Date & time : 20-Aug-2025 5:15:36 PM
#
# ================================================================================
# FILE: DC-25-2210.pdf
# ================================================================================
#
# --- Page 1 ---
# Bitopi Group
# Baridhi Garments Ltd.
# SFB# 7 & 8 (Ground Floor to 5th Floor) Cumilla EPZ, Cumilla, Bangladesh.
# Export Delivery Challan/Gate Pass
# SL No: DC-25-2210 Date: 25-May-2025
# To: KDS Logistics ltd. Driver Name: Md Jahangir
# Address: Ghoramara Sonaichari,Sitakuda,Chattogram. Cell Number: 01814-700410
# Export L/C No : 554 License No: CG0000363
# Buyer: H&M Truck No: KU-TA-11-0514
# Vehicle Information: Cover Van Single Lock No: 1391919 Container SL No:
# S/N Description of Goods/PO Style Invoice No Qty No of Pkgs Remarks Net Weight Gross Weight
# 1 374509 MK Scott Reg Blosuon 41446125 50 3 AEW075 38.87 41.83
# 2 374509 MK Scott Reg Blosuon 41446225 230 12 SEW001 180.27 192.09
# 3 378600 MK Scott Reg Blosuon 41446525 68 5 AEW244 54.42 61.08
# 4 374509 MK Scott Reg Blosuon 41445925 154 8 COW202 118.28 126.16
# 5 357670 MK Scott Reg Blosuon 41445525 383 21 KRW452 307.13 329.43
# 6 374509 MK Scott Reg Blosuon 41445625 458 24 BEW015 360.66 384.30
# 7 373318 ERICA Twill Jacket S2 41423425 645 40 SEW065 530.88 570.26
# 8 367576 JULES JACKET S2 41421725 125 6 AEW075 58.00 66.02
# 9 367611 NICKY Jogger 3PACK S2 BGL 41424125 10 1 KRW454 6.21 7.12
# 10 367572 JULES JACKET S2 41421225 244 11 SEW065 114.85 125.65
# 11 367572 JULES JACKET S2 41420825 20 1 AEW244 9.52 10.50
# 12 379606 NICKY Jogger 3PACK S2 BGL 41424625 1091 70 SEW065 627.72 691.29
# 13 378602 MK Scott Reg Blosuon 41447925 146 10 SEW065 116.58 130.04
# 14 357676 MK Scott Reg Blosuon 41447225 215 12 KRW452 172.70 184.50
# 15 378602 MK Scott Reg Blosuon 41447325 20 2 AEW244 15.98 18.56
# 16 378600 MK Scott Reg Blosuon 41446725 224 14 SEW065 177.93 196.97
# Total: 4083 240
# Received on behalf of Transport agency Store Manager HR/Admin Authorised Signature
# Page 1 of 1 Print Date & time : 20-Aug-2025 5:16:31 PM
#
# ================================================================================
# FILE: DC-25-2213.pdf
# ================================================================================
#
# --- Page 1 ---
# Bitopi Group
# Baridhi Garments Ltd.
# SFB# 7 & 8 (Ground Floor to 5th Floor) Cumilla EPZ, Cumilla, Bangladesh.
# Export Delivery Challan/Gate Pass
# SL No: DC-25-2213 Date: 25-May-2025
# To: Summit Alliance Port Litmited (OCL) Driver Name: Md Ripon
# Address: Katghar, North Patenga,Chattogram. Cell Number: 01877-215431
# Export L/C No : 554/564 License No: 0008
# Buyer: H&M Truck No: DM-TA-18-2724
# Vehicle Information: Cover Van Single Lock No: 1391918 Container SL No:
# S/N Description of Goods/PO Style Invoice No Qty No of Pkgs Remarks Net Weight Gross Weight
# 1 374509 MK Scott Reg Blosuon 41446025 163 9 DEW004 128.02 138.03
# 2 367576 JULES JACKET S2 41421525 2219 95 DEW004 1036.56 1165.76
# 3 367576 JULES JACKET S2 41421625 2319 103 PLW519 1075.89 1217.18
# 4 367572 JULES JACKET S2 41420925 191 9 ESW267 90.60 99.44
# 5 379606 NICKY Jogger 3PACK S2 BGL 41424325 645 42 ESW267 364.65 402.74
# 6 374509 MK Scott Reg Blosuon 41445725 247 14 ESW038 194.49 208.23
# 7 378602 MK Scott Reg Blosuon 41447425 129 8 ESW267 102.20 113.08
# 8 378600 MK Scott Reg Blosuon 41446625 274 17 ESW267 216.23 239.21
# Total: 6187 297
# Received on behalf of Transport agency Store Manager HR/Admin Authorised Signature
# Page 1 of 1 Print Date & time : 20-Aug-2025 5:17:22 PM

# %%
import os
import camelot
import pandas as pd

pdf_dir = r"C:\Users\Altersense\Desktop\ERP-RPA\Challan"

for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        pdf_path = os.path.join(pdf_dir, filename)
        print(f"\n{'='*80}")
        print(f"FILE: {filename}")
        print(f"{'='*80}")
        
        try:
            # Extract tables from PDF using Camelot
            tables = camelot.read_pdf(pdf_path, pages='all', flavor='lattice')
            
            print(f"Number of tables found: {tables.n}")
            
            if tables.n == 0:
                print("No tables found in this PDF.")
                continue
            
            for i, table in enumerate(tables):
                print(f"\n--- Table {i+1} ---")
                print(f"Accuracy: {table.accuracy:.2f}")
                print(f"Whitespace: {table.whitespace:.2f}")
                print(f"Order: {table.order}")
                print(f"Page: {table.page}")
                
                # Get the DataFrame
                df = table.df
                
                print("\nDataFrame:")
                print(df)
                print(f"\nShape: {df.shape}")
                print("-" * 40)
                
                # Optional: Save each table to CSV
                # csv_filename = f"{os.path.splitext(filename)[0]}_table_{i+1}.csv"
                # df.to_csv(os.path.join(pdf_dir, csv_filename), index=False)
                        
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
# Out:
# ================================================================================
# FILE: DC-25-2209.pdf
# ================================================================================
# Number of tables found: 1
#
# --- Table 1 ---
# Accuracy: 100.00
# Whitespace: 3.92
# Order: 1
# Page: 1
#
# DataFrame:
#       0                        1                          2           3     4  \
# 0   S/N  Description of Goods/PO                      Style  Invoice No   Qty
# 1     1                   374509       MK Scott Reg Blosuon    41445825   440
# 2     2                   373318      ERICA Twill Jacket S2    41423325   177
# 3     3                   367576            JULES JACKET S2    41421825  1462
# 4     4                   367611  NICKY Jogger 3PACK S2 BGL    41424225    34
# 5     5                   367611  NICKY Jogger 3PACK S2 BGL    41424025    36
# 6     6                   367572            JULES JACKET S2    41421025   161
# 7     7                   367572            JULES JACKET S2    41421125    88
# 8     8                   247879       SOFIE QUILTED JKT S1    41420525   937
# 9     9                   379606  NICKY Jogger 3PACK S2 BGL    41424425   543
# 10   10                   379606  NICKY Jogger 3PACK S2 BGL    41424425    87
# 11   11                   378602       MK Scott Reg Blosuon    41424525    96
# 12   12                   378602       MK Scott Reg Blosuon    41447625    51
# 13   13                   357676       MK Scott Reg Blosuon    41447125   590
# 14   14                   378600       MK Scott Reg Blosuon    41446725   224
# 15   15                   257721       FINN Chore Jacket S1    41420625   345
# 16                                                               Total:  5271
#
#              5        6           7             8
# 0   No of Pkgs  Remarks  Net Weight  Gross Weight
# 1           23   ITW018      345.36        368.02
# 2           11   TRW191      142.00        152.81
# 3           63   TRW059      678.22        763.76
# 4            3   AUW270       19.41         22.01
# 5            3   JPW171       21.30         23.90
# 6            8   ITW128       76.49         84.37
# 7            5   TRW191       40.87         45.77
# 8           81   CLW093      403.34        495.68
# 9           34   ITW128      307.16        338.10
# 10           7   TRW191       49.61         55.72
# 11           6   ITW128       76.33         84.49
# 12           4   TRW191       40.68         45.98
# 13          32   JPW053      467.32        501.17
# 14          14   ITW128      176.80        195.70
# 15          10   CLW093      108.05        118.06
# 16         304
#
# Shape: (17, 9)
# ----------------------------------------
#
# ================================================================================
# FILE: DC-25-2210.pdf
# ================================================================================
# Number of tables found: 1
#
# --- Table 1 ---
# Accuracy: 100.00
# Whitespace: 3.70
# Order: 1
# Page: 1
#
# DataFrame:
#       0                        1                          2           3     4  \
# 0   S/N  Description of Goods/PO                      Style  Invoice No   Qty
# 1     1                   374509       MK Scott Reg Blosuon    41446125    50
# 2     2                   374509       MK Scott Reg Blosuon    41446225   230
# 3     3                   378600       MK Scott Reg Blosuon    41446525    68
# 4     4                   374509       MK Scott Reg Blosuon    41445925   154
# 5     5                   357670       MK Scott Reg Blosuon    41445525   383
# 6     6                   374509       MK Scott Reg Blosuon    41445625   458
# 7     7                   373318      ERICA Twill Jacket S2    41423425   645
# 8     8                   367576            JULES JACKET S2    41421725   125
# 9     9                   367611  NICKY Jogger 3PACK S2 BGL    41424125    10
# 10   10                   367572            JULES JACKET S2    41421225   244
# 11   11                   367572            JULES JACKET S2    41420825    20
# 12   12                   379606  NICKY Jogger 3PACK S2 BGL    41424625  1091
# 13   13                   378602       MK Scott Reg Blosuon    41447925   146
# 14   14                   357676       MK Scott Reg Blosuon    41447225   215
# 15   15                   378602       MK Scott Reg Blosuon    41447325    20
# 16   16                   378600       MK Scott Reg Blosuon    41446725   224
# 17                                                               Total:  4083
#
#              5        6           7             8
# 0   No of Pkgs  Remarks  Net Weight  Gross Weight
# 1            3   AEW075       38.87         41.83
# 2           12   SEW001      180.27        192.09
# 3            5   AEW244       54.42         61.08
# 4            8   COW202      118.28        126.16
# 5           21   KRW452      307.13        329.43
# 6           24   BEW015      360.66        384.30
# 7           40   SEW065      530.88        570.26
# 8            6   AEW075       58.00         66.02
# 9            1   KRW454        6.21          7.12
# 10          11   SEW065      114.85        125.65
# 11           1   AEW244        9.52         10.50
# 12          70   SEW065      627.72        691.29
# 13          10   SEW065      116.58        130.04
# 14          12   KRW452      172.70        184.50
# 15           2   AEW244       15.98         18.56
# 16          14   SEW065      177.93        196.97
# 17         240
#
# Shape: (18, 9)
# ----------------------------------------
#
# ================================================================================
# FILE: DC-25-2213.pdf
# ================================================================================
# Number of tables found: 1
#
# --- Table 1 ---
# Accuracy: 100.00
# Whitespace: 6.67
# Order: 1
# Page: 1
#
# DataFrame:
#      0                        1                          2           3     4  \
# 0  S/N  Description of Goods/PO                      Style  Invoice No   Qty
# 1    1                   374509       MK Scott Reg Blosuon    41446025   163
# 2    2                   367576            JULES JACKET S2    41421525  2219
# 3    3                   367576            JULES JACKET S2    41421625  2319
# 4    4                   367572            JULES JACKET S2    41420925   191
# 5    5                   379606  NICKY Jogger 3PACK S2 BGL    41424325   645
# 6    6                   374509       MK Scott Reg Blosuon    41445725   247
# 7    7                   378602       MK Scott Reg Blosuon    41447425   129
# 8    8                   378600       MK Scott Reg Blosuon    41446625   274
# 9                                                               Total:  6187
#
#             5        6           7             8
# 0  No of Pkgs  Remarks  Net Weight  Gross Weight
# 1           9   DEW004      128.02        138.03
# 2          95   DEW004     1036.56       1165.76
# 3         103   PLW519     1075.89       1217.18
# 4           9   ESW267       90.60         99.44
# 5          42   ESW267      364.65        402.74
# 6          14   ESW038      194.49        208.23
# 7           8   ESW267      102.20        113.08
# 8          17   ESW267      216.23        239.21
# 9         297
#
# Shape: (10, 9)
# ----------------------------------------
